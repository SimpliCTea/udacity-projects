# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import joblib
import pandas as pd
from sqlalchemy import create_engine

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, precision_recall_fscore_support

# %%
# load data from database
engine = create_engine('sqlite:///disaster_response_pipeline.db')
df = pd.read_sql_table('disaster_messages', con=engine)
X_labels = ['id', 'message', 'original', 'genre']
X = df[X_labels]
Y = df.drop(columns=X_labels)

# %%
X.head(1)
# Out:
#    id                                            message  \
# 0   2  Weather update - a cold front from Cuba that c...
#
#                                             original   genre
# 0  Un front froid se retrouve sur Cuba ce matin. ...  direct

# %%
Y.head(1)
# Out:
#    related  request  offer  aid_related  medical_help  medical_products  \
# 0        1        0      0            0             0                 0
#
#    search_and_rescue  security  military  child_alone  ...  aid_centers  \
# 0                  0         0         0            0  ...            0
#
#    other_infrastructure  weather_related  floods  storm  fire  earthquake  \
# 0                     0                0       0      0     0           0
#
#    cold  other_weather  direct_report
# 0     0              0              0
#
# [1 rows x 36 columns]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    lemmatizer = WordNetLemmatizer()
    
    text = re.sub(r'[^a-zA-Z0-9]', ' ', text.lower())
    
    token_list = word_tokenize(text)
    token_list = [token.strip() for token in token_list if token not in stopwords.words("english")]
    token_list = [lemmatizer.lemmatize(token) for token in token_list]
        
    return token_list

# %%
tokenize(X.message[7])
# Out:
# ['please', 'need', 'tent', 'water', 'silo', 'thank']

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vectorizer', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultiOutputClassifier(RandomForestClassifier()))],
    verbose=True
)

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vectorizer',
#    CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                    dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                    lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                    ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                    strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                    tokenizer=<function tokenize at 0x000001BC08CDB158>,
#                    vocabulary=None)),
#   ('tfidf',
#    TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)),
#   ('classifier',
#    MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                           class_weight=None,
#                                                           criterion='gini',
#                                                           max_depth=None,
#                                                           max_features='auto',
#                                                           max_leaf_nodes=None,
#                                                           min_impurity_decrease=0.0,
#                                                           min_impurity_split=None,
#                                                           min_samples_leaf=1,
#                                                           min_samples_split=2,
#                                                           min_weight_fraction_leaf=0.0,
#                                                           n_estimators='warn',
#                                                           n_jobs=None,
#                                                           oob_score=False,
#                                                           random_state=None,
#                                                           verbose=0,
#                                                           warm_start=False),
#                          n_jobs=-1))],
#  'verbose': True,
#  'vectorizer': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                  dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                  lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                  ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                  strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                  tokenizer=<function tokenize at 0x000001BC08CDB158>,
#                  vocabulary=None),
#  'tfidf': TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True),
#  'classifier': MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                         class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features='auto',
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         n_estimators='warn',
#                                                         n_jobs=None,
#                                                         oob_score=False,
#                                                         random_state=None,
#                                                         verbose=0,
#                                                         warm_start=False),
#                        n_jobs=-1),
#  'vectorizer__analyzer': 'word',
#  'vectorizer__binary': False,
#  'vectorizer__decode_error': 'strict',
#  'vectorizer__dtype': numpy.int64,
#  'vectorizer__encoding': 'utf-8',
#  'vectorizer__input': 'content',
#  'vectorizer__lowercase': True,
#  'vectorizer__max_df': 1.0,
#  'vectorizer__max_features': None,
#  'vectorizer__min_df': 1,
#  'vectorizer__ngram_range': (1, 1),
#  'vectorizer__preprocessor': None,
#  'vectorizer__stop_words': None,
#  'vectorizer__strip_accents': None,
#  'vectorizer__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vectorizer__tokenizer': <function __main__.tokenize(text)>,
#  'vectorizer__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'classifier__estimator__bootstrap': True,
#  'classifier__estimator__class_weight': None,
#  'classifier__estimator__criterion': 'gini',
#  'classifier__estimator__max_depth': None,
#  'classifier__estimator__max_features': 'auto',
#  'classifier__estimator__max_leaf_nodes': None,
#  'classifier__estimator__min_impurity_decrease': 0.0,
#  'classifier__estimator__min_impurity_split': None,
#  'classifier__estimator__min_samples_leaf': 1,
#  'classifier__estimator__min_samples_split': 2,
#  'classifier__estimator__min_weight_fraction_leaf': 0.0,
#  'classifier__estimator__n_estimators': 'warn',
#  'classifier__estimator__n_jobs': None,
#  'classifier__estimator__oob_score': False,
#  'classifier__estimator__random_state': None,
#  'classifier__estimator__verbose': 0,
#  'classifier__estimator__warm_start': False,
#  'classifier__estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators='warn',
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  'classifier__n_jobs': -1}

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X['message'], Y)

# %%
X_test.shape
# Out:
# (6545,)

# %%
pipeline.fit(X_train, Y_train);
# Out:
# [Pipeline] ........ (step 1 of 3) Processing vectorizer, total= 3.9min
# [Pipeline] ............. (step 2 of 3) Processing tfidf, total=   0.1s
# [Pipeline] ........ (step 3 of 3) Processing classifier, total=  33.6s

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
Y_pred = pipeline.predict(X_test)

# %%
classification_reports = {}
for i, column in enumerate(Y_test):
    classification_reports[column] = classification_report(Y_test.values[i], Y_pred[i])
    print('Label: {}'.format(column))
    print('-'*50)
    print(classification_reports[column])
    #print(precision_recall_fscore_support(Y_test.values[i], Y_pred[i]))
# Out:
# Label: related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        33
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        36
#    macro avg       0.99      0.83      0.89        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: request
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: offer
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        33
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.67      0.74        36
# weighted avg       0.95      0.94      0.93        36
#
# Label: aid_related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: medical_help
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: medical_products
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        32
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.75      0.82        36
# weighted avg       0.95      0.94      0.94        36
#
# Label: search_and_rescue
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: security
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: military
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: child_alone
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        31
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.90      0.94        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: water
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: food
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: shelter
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: clothing
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: money
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        30
#            1       1.00      0.33      0.50         6
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.67      0.72        36
# weighted avg       0.90      0.89      0.86        36
#
# Label: missing_people
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: refugees
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        33
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        36
#    macro avg       0.99      0.83      0.89        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: death
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96        32
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.92        36
#    macro avg       0.96      0.62      0.68        36
# weighted avg       0.92      0.92      0.89        36
#
# Label: other_aid
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: infrastructure_related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        30
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.58      0.60        36
# weighted avg       0.88      0.86      0.82        36
#
# Label: transport
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        31
#            1       1.00      0.20      0.33         5
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.60      0.64        36
# weighted avg       0.90      0.89      0.86        36
#
# Label: buildings
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.97        36
#    macro avg       0.33      0.33      0.33        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: electricity
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.94        36
#    macro avg       0.50      0.47      0.49        36
# weighted avg       1.00      0.94      0.97        36
#
# Label: tools
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90        29
#            1       0.67      0.29      0.40         7
#
#     accuracy                           0.83        36
#    macro avg       0.76      0.63      0.65        36
# weighted avg       0.81      0.83      0.81        36
#
# Label: hospitals
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: shops
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: aid_centers
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        33
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        36
#    macro avg       0.99      0.83      0.89        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: other_infrastructure
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        29
#            1       1.00      0.29      0.44         7
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.64      0.68        36
# weighted avg       0.88      0.86      0.83        36
#
# Label: weather_related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        28
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.78        36
#    macro avg       0.39      0.50      0.44        36
# weighted avg       0.60      0.78      0.68        36
#
# Label: floods
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        29
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.92        36
#    macro avg       0.95      0.79      0.84        36
# weighted avg       0.92      0.92      0.91        36
#
# Label: storm
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        31
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.80      0.86        36
# weighted avg       0.95      0.94      0.94        36
#
# Label: fire
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96        32
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.92        36
#    macro avg       0.96      0.62      0.68        36
# weighted avg       0.92      0.92      0.89        36
#
# Label: earthquake
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        30
#            1       1.00      0.83      0.91         6
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.92      0.95        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: cold
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        33
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.67      0.74        36
# weighted avg       0.95      0.94      0.93        36
#
# Label: other_weather
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        29
#            1       1.00      0.29      0.44         7
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.64      0.68        36
# weighted avg       0.88      0.86      0.83        36
#
# Label: direct_report
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        34
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.97        36
#    macro avg       0.99      0.75      0.83        36
# weighted avg       0.97      0.97      0.97        36
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {
    'classifier__estimator__n_estimators': [10, 25, 50],
    'classifier__estimator__min_samples_split': [2,4,6],
    'classifier__estimator__max_features': [.1, .25, .5, 'sqrt', 'log2']
}

cv = GridSearchCV(pipeline, parameters, n_jobs=-1, verbose=3)

# %%
cv.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 101.1min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 703.0min
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed: 741.3min finished
# [Pipeline] ........ (step 1 of 3) Processing vectorizer, total= 4.0min
# [Pipeline] ............. (step 2 of 3) Processing tfidf, total=   0.0s
# [Pipeline] ........ (step 3 of 3) Processing classifier, total=15.0min
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vectorizer',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words=None,
#                                                         strip_accen...
#                                                                                                random_state=None,
#                                                                                                verbose=0,
#                                                                                                warm_start=False),
#                                                               n_jobs=None))],
#                                 verbose=True),
#              iid='warn', n_jobs=-1,
#              param_grid={'classifier__estimator__max_features': [0.1, 0.25, 0.5,
#                                                                  'sqrt',
#                                                                  'log2'],
#                          'classifier__estimator__min_samples_split': [2, 4, 6],
#                          'classifier__estimator__n_estimators': [10, 25, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
pd.DataFrame(cv.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      495.196485      2.519397       147.554188        1.713290
# 1      830.910966     52.967946       148.520633        1.841346
# 2     1333.966658     28.573162       153.579571        1.710992
# 3      486.393711      9.149642       145.635952        1.490548
# 4      796.908459     10.614006       148.361388        1.809247
# 5     1289.159445      4.271427       157.815626        6.035836
# 6      484.836922     20.462418       145.896134        5.294757
# 7      770.243870     10.863134       148.126542        2.506219
# 8     1259.073857     15.358330       152.179540        2.069410
# 9      753.371016     31.074915       146.082693        1.403461
# 10    1389.016109      1.582801       146.425501        2.157725
# 11    2462.014491     15.030968       152.236343        5.057215
# 12     684.567076     11.971698       141.720360        1.145863
# 13    1349.703098     25.207301       144.671505        2.452473
# 14    2418.230924     33.431416       150.718042        2.416486
# 15     684.835466     11.481790       140.356982        3.787674
# 16    1339.003619      3.174841       148.150846        3.279669
# 17    2358.253386     21.578167       149.516397        3.935522
# 18    1114.591043     55.191429       141.304431        1.619968
# 19    2297.828949      5.259013       145.975434        2.086994
# 20    4352.758882     26.603833       151.147804        4.389660
# 21    1050.235575      6.773734       139.689356        1.076932
# 22    2289.660340      5.405048       140.853025        3.262254
# 23    4242.974325     23.666381       147.585512        1.890258
# 24    1036.995465     31.919967       138.955777        1.571815
# 25    2246.593495     10.266142       139.634559        1.670017
# 26    4369.239234     78.890076       157.769350        9.625672
# 27     319.391472      1.849743       136.877967        1.699844
# 28     414.117744      6.165506       143.910949        1.790268
# 29     580.968754     20.743017       163.680962        5.645737
# 30     355.185172     11.504590       157.002946        3.670440
# 31     441.102988     13.784932       157.889269        2.202635
# 32     546.202816      9.643520       168.787370        1.956214
# 33     342.312853     11.914581       149.759760        4.262074
# 34     413.045867      7.982201       156.222241        6.412965
# 35     510.604679      2.967754       169.558106        1.233212
# 36     369.244105      5.262202       152.596965        3.890972
# 37     481.929772     12.773492       159.235512        4.724481
# 38     637.415110     16.591982       183.369016       10.868718
# 39     343.839818     10.513029       152.458713        1.490033
# 40     434.564532      9.592380       161.433936        3.111794
# 41     557.295809      6.552127       181.579707       11.732815
# 42     331.643492      9.806223       151.722799        3.106191
# 43     413.846580      2.748057       163.149257        4.581909
# 44     506.303644     21.199148       150.573642       36.850049
#
#    param_classifier__estimator__max_features  \
# 0                                        0.1
# 1                                        0.1
# 2                                        0.1
# 3                                        0.1
# 4                                        0.1
# 5                                        0.1
# 6                                        0.1
# 7                                        0.1
# 8                                        0.1
# 9                                       0.25
# 10                                      0.25
# 11                                      0.25
# 12                                      0.25
# 13                                      0.25
# 14                                      0.25
# 15                                      0.25
# 16                                      0.25
# 17                                      0.25
# 18                                       0.5
# 19                                       0.5
# 20                                       0.5
# 21                                       0.5
# 22                                       0.5
# 23                                       0.5
# 24                                       0.5
# 25                                       0.5
# 26                                       0.5
# 27                                      sqrt
# 28                                      sqrt
# 29                                      sqrt
# 30                                      sqrt
# 31                                      sqrt
# 32                                      sqrt
# 33                                      sqrt
# 34                                      sqrt
# 35                                      sqrt
# 36                                      log2
# 37                                      log2
# 38                                      log2
# 39                                      log2
# 40                                      log2
# 41                                      log2
# 42                                      log2
# 43                                      log2
# 44                                      log2
#
#    param_classifier__estimator__min_samples_split  \
# 0                                               2
# 1                                               2
# 2                                               2
# 3                                               4
# 4                                               4
# 5                                               4
# 6                                               6
# 7                                               6
# 8                                               6
# 9                                               2
# 10                                              2
# 11                                              2
# 12                                              4
# 13                                              4
# 14                                              4
# 15                                              6
# 16                                              6
# 17                                              6
# 18                                              2
# 19                                              2
# 20                                              2
# 21                                              4
# 22                                              4
# 23                                              4
# 24                                              6
# 25                                              6
# 26                                              6
# 27                                              2
# 28                                              2
# 29                                              2
# 30                                              4
# 31                                              4
# 32                                              4
# 33                                              6
# 34                                              6
# 35                                              6
# 36                                              2
# 37                                              2
# 38                                              2
# 39                                              4
# 40                                              4
# 41                                              4
# 42                                              6
# 43                                              6
# 44                                              6
#
#    param_classifier__estimator__n_estimators  \
# 0                                         10
# 1                                         25
# 2                                         50
# 3                                         10
# 4                                         25
# 5                                         50
# 6                                         10
# 7                                         25
# 8                                         50
# 9                                         10
# 10                                        25
# 11                                        50
# 12                                        10
# 13                                        25
# 14                                        50
# 15                                        10
# 16                                        25
# 17                                        50
# 18                                        10
# 19                                        25
# 20                                        50
# 21                                        10
# 22                                        25
# 23                                        50
# 24                                        10
# 25                                        25
# 26                                        50
# 27                                        10
# 28                                        25
# 29                                        50
# 30                                        10
# 31                                        25
# 32                                        50
# 33                                        10
# 34                                        25
# 35                                        50
# 36                                        10
# 37                                        25
# 38                                        50
# 39                                        10
# 40                                        25
# 41                                        50
# 42                                        10
# 43                                        25
# 44                                        50
#
#                                                params  split0_test_score  \
# 0   {'classifier__estimator__max_features': 0.1, '...           0.254698
# 1   {'classifier__estimator__max_features': 0.1, '...           0.264018
# 2   {'classifier__estimator__max_features': 0.1, '...           0.275630
# 3   {'classifier__estimator__max_features': 0.1, '...           0.249809
# 4   {'classifier__estimator__max_features': 0.1, '...           0.265241
# 5   {'classifier__estimator__max_features': 0.1, '...           0.267074
# 6   {'classifier__estimator__max_features': 0.1, '...           0.249351
# 7   {'classifier__estimator__max_features': 0.1, '...           0.266616
# 8   {'classifier__estimator__max_features': 0.1, '...           0.272880
# 9   {'classifier__estimator__max_features': 0.25, ...           0.255921
# 10  {'classifier__estimator__max_features': 0.25, ...           0.269060
# 11  {'classifier__estimator__max_features': 0.25, ...           0.266005
# 12  {'classifier__estimator__max_features': 0.25, ...           0.259129
# 13  {'classifier__estimator__max_features': 0.25, ...           0.259587
# 14  {'classifier__estimator__max_features': 0.25, ...           0.271963
# 15  {'classifier__estimator__max_features': 0.25, ...           0.253170
# 16  {'classifier__estimator__max_features': 0.25, ...           0.258060
# 17  {'classifier__estimator__max_features': 0.25, ...           0.267380
# 18  {'classifier__estimator__max_features': 0.5, '...           0.256837
# 19  {'classifier__estimator__max_features': 0.5, '...           0.264629
# 20  {'classifier__estimator__max_features': 0.5, '...           0.268296
# 21  {'classifier__estimator__max_features': 0.5, '...           0.250573
# 22  {'classifier__estimator__max_features': 0.5, '...           0.257143
# 23  {'classifier__estimator__max_features': 0.5, '...           0.266310
# 24  {'classifier__estimator__max_features': 0.5, '...           0.250573
# 25  {'classifier__estimator__max_features': 0.5, '...           0.263407
# 26  {'classifier__estimator__max_features': 0.5, '...           0.267227
# 27  {'classifier__estimator__max_features': 'sqrt'...           0.230252
# 28  {'classifier__estimator__max_features': 'sqrt'...           0.242475
# 29  {'classifier__estimator__max_features': 'sqrt'...           0.254087
# 30  {'classifier__estimator__max_features': 'sqrt'...           0.229335
# 31  {'classifier__estimator__max_features': 'sqrt'...           0.237892
# 32  {'classifier__estimator__max_features': 'sqrt'...           0.249503
# 33  {'classifier__estimator__max_features': 'sqrt'...           0.226891
# 34  {'classifier__estimator__max_features': 'sqrt'...           0.241253
# 35  {'classifier__estimator__max_features': 'sqrt'...           0.246142
# 36  {'classifier__estimator__max_features': 'log2'...           0.219710
# 37  {'classifier__estimator__max_features': 'log2'...           0.223071
# 38  {'classifier__estimator__max_features': 'log2'...           0.223988
# 39  {'classifier__estimator__max_features': 'log2'...           0.205195
# 40  {'classifier__estimator__max_features': 'log2'...           0.217418
# 41  {'classifier__estimator__max_features': 'log2'...           0.225516
# 42  {'classifier__estimator__max_features': 'log2'...           0.200306
# 43  {'classifier__estimator__max_features': 'log2'...           0.212834
# 44  {'classifier__estimator__max_features': 'log2'...           0.216196
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.267838           0.266769         0.263102        0.005958
# 1            0.271658           0.279144         0.271607        0.006175
# 2            0.281436           0.282964         0.280010        0.003159
# 3            0.271199           0.261727         0.260912        0.008752
# 4            0.278380           0.277158         0.273593        0.005927
# 5            0.285256           0.283422         0.278584        0.008173
# 6            0.259740           0.269519         0.259537        0.008235
# 7            0.281283           0.277769         0.275223        0.006253
# 8            0.284492           0.281283         0.279552        0.004896
# 9            0.267991           0.259893         0.261268        0.005023
# 10           0.269977           0.272422         0.270486        0.001419
# 11           0.278992           0.278839         0.274612        0.006086
# 12           0.270283           0.269060         0.266157        0.004995
# 13           0.277617           0.273186         0.270130        0.007671
# 14           0.277005           0.285103         0.278024        0.005412
# 15           0.270283           0.256837         0.260097        0.007356
# 16           0.277005           0.275477         0.270181        0.008594
# 17           0.278075           0.283117         0.276190        0.006561
# 18           0.262185           0.261727         0.260250        0.002420
# 19           0.274561           0.271505         0.270232        0.004153
# 20           0.278992           0.274561         0.273950        0.004388
# 21           0.264171           0.258824         0.257856        0.005593
# 22           0.273338           0.273186         0.267889        0.007599
# 23           0.278380           0.277617         0.274102        0.005519
# 24           0.262185           0.257907         0.256888        0.004795
# 25           0.274866           0.270894         0.269722        0.004751
# 26           0.283881           0.273338         0.274815        0.006879
# 27           0.241253           0.245225         0.238910        0.006333
# 28           0.254087           0.255615         0.250726        0.005867
# 29           0.266921           0.260199         0.260402        0.005242
# 30           0.234377           0.238350         0.234021        0.003689
# 31           0.253782           0.255004         0.248892        0.007795
# 32           0.263407           0.257907         0.256939        0.005717
# 33           0.237433           0.240031         0.234785        0.005682
# 34           0.252559           0.258212         0.250675        0.007051
# 35           0.259129           0.258060         0.254444        0.005886
# 36           0.226585           0.228724         0.225006        0.003846
# 37           0.228877           0.230558         0.227502        0.003207
# 38           0.244461           0.244920         0.237790        0.009761
# 39           0.215584           0.210848         0.210542        0.004247
# 40           0.226432           0.232697         0.225516        0.006271
# 41           0.232544           0.236516         0.231525        0.004548
# 42           0.210848           0.213445         0.208200        0.005682
# 43           0.227196           0.228724         0.222918        0.007158
# 44           0.234683           0.233155         0.228011        0.008378
#
#     rank_test_score
# 0                20
# 1                12
# 2                 1
# 3                22
# 4                11
# 5                 3
# 6                26
# 7                 6
# 8                 2
# 9                21
# 10               13
# 11                8
# 12               19
# 13               16
# 14                4
# 15               25
# 16               15
# 17                5
# 18               24
# 19               14
# 20               10
# 21               27
# 22               18
# 23                9
# 24               29
# 25               17
# 26                7
# 27               34
# 28               31
# 29               23
# 30               37
# 31               33
# 32               28
# 33               36
# 34               32
# 35               30
# 36               42
# 37               40
# 38               35
# 39               44
# 40               41
# 41               38
# 42               45
# 43               43
# 44               39

# %%
cv.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function toke...
#                  MultiOutputClassifier(estimator=RandomForestClassifier(bootstrap=True,
#                                                                         class_weight=None,
#                                                                         criterion='gini',
#                                                                         max_depth=None,
#                                                                         max_features=0.1,
#                                                                         max_leaf_nodes=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split=None,
#                                                                         min_samples_leaf=1,
#                                                                         min_samples_split=2,
#                                                                         min_weight_fraction_leaf=0.0,
#                                                                         n_estimators=50,
#                                                                         n_jobs=None,
#                                                                         oob_score=False,
#                                                                         random_state=None,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                        n_jobs=None))],
#          verbose=True)

# %%
cv.best_params_
# Out:
# {'classifier__estimator__max_features': 0.1,
#  'classifier__estimator__min_samples_split': 2,
#  'classifier__estimator__n_estimators': 50}

# %%
Y_pred_best = cv.predict(X_test)

# %%
classification_reports_best = {}
for i, column in enumerate(Y_test):
    classification_reports_best[column] = classification_report(Y_test.values[i], Y_pred_best[i])
    print('Label: {}'.format(column))
    print('-'*50)
    print(classification_reports_best[column])
    #print(precision_recall_fscore_support(Y_test.values[i], Y_pred[i]))
# Out:
# Label: related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: request
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: offer
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        33
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.67      0.74        36
# weighted avg       0.95      0.94      0.93        36
#
# Label: aid_related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: medical_help
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: medical_products
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: search_and_rescue
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: security
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: military
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: child_alone
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: water
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: food
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: shelter
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: clothing
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: money
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        30
#            1       1.00      0.17      0.29         6
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.58      0.60        36
# weighted avg       0.88      0.86      0.82        36
#
# Label: missing_people
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: refugees
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: death
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        32
#            1       1.00      0.50      0.67         4
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.75      0.82        36
# weighted avg       0.95      0.94      0.94        36
#
# Label: other_aid
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.94        36
#    macro avg       0.50      0.47      0.49        36
# weighted avg       1.00      0.94      0.97        36
#
# Label: infrastructure_related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        30
#            1       1.00      0.33      0.50         6
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.67      0.72        36
# weighted avg       0.90      0.89      0.86        36
#
# Label: transport
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        31
#            1       0.00      0.00      0.00         5
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.86        36
#    macro avg       0.30      0.33      0.31        36
# weighted avg       0.76      0.86      0.81        36
#
# Label: buildings
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        35
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.97        36
#    macro avg       0.49      0.50      0.49        36
# weighted avg       0.95      0.97      0.96        36
#
# Label: electricity
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.94        36
#    macro avg       0.50      0.47      0.49        36
# weighted avg       1.00      0.94      0.97        36
#
# Label: tools
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        29
#            1       0.75      0.43      0.55         7
#
#     accuracy                           0.86        36
#    macro avg       0.81      0.70      0.73        36
# weighted avg       0.85      0.86      0.85        36
#
# Label: hospitals
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        36
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.97        36
#    macro avg       0.50      0.49      0.49        36
# weighted avg       1.00      0.97      0.99        36
#
# Label: shops
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Label: aid_centers
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        33
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.94        36
#    macro avg       0.82      0.82      0.82        36
# weighted avg       0.94      0.94      0.94        36
#
# Label: other_infrastructure
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        29
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.92        36
#    macro avg       0.95      0.79      0.84        36
# weighted avg       0.92      0.92      0.91        36
#
# Label: weather_related
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89        28
#            1       1.00      0.12      0.22         8
#
#     accuracy                           0.81        36
#    macro avg       0.90      0.56      0.56        36
# weighted avg       0.84      0.81      0.74        36
#
# Label: floods
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        29
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.86      0.90        36
# weighted avg       0.95      0.94      0.94        36
#
# Label: storm
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        31
#            1       1.00      0.80      0.89         5
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.90      0.94        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: fire
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96        32
#            1       1.00      0.25      0.40         4
#
#     accuracy                           0.92        36
#    macro avg       0.96      0.62      0.68        36
# weighted avg       0.92      0.92      0.89        36
#
# Label: earthquake
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        30
#            1       0.67      1.00      0.80         6
#
#     accuracy                           0.92        36
#    macro avg       0.83      0.95      0.87        36
# weighted avg       0.94      0.92      0.92        36
#
# Label: cold
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        33
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.97        36
#    macro avg       0.99      0.83      0.89        36
# weighted avg       0.97      0.97      0.97        36
#
# Label: other_weather
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        29
#            1       0.00      0.00      0.00         7
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.81        36
#    macro avg       0.28      0.33      0.30        36
# weighted avg       0.67      0.81      0.73        36
#
# Label: direct_report
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        34
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.97        36
#    macro avg       0.99      0.75      0.83        36
# weighted avg       0.97      0.97      0.97        36
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
file_name = 'classifier.pkl'
joblib.dump(cv.best_estimator_, file_name)
# Out:
# ['classifier.pkl']

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
